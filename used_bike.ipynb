# %%
import numpy as np

# %%
import pandas as pd

# %%
pd.__version__                 #for getting the version
# Out:
# '2.2.2'

# %%
df = pd.read_csv('Used_Bikes.csv')                  #to read used_bike file
print(df)
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
print(df)
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
df.head()           #for top values
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#          owner  age  power          brand
# 0  First Owner  3.0  110.0            TVS
# 1  First Owner  4.0  350.0  Royal Enfield
# 2  First Owner  8.0  675.0        Triumph
# 3  First Owner  4.0  180.0            TVS
# 4  First Owner  3.0  150.0         Yamaha

# %%
df.tail()       #for last valuesz
# Out:
#                        bike_name    price    city  kms_driven        owner  \
# 32643     Hero Passion Pro 100cc  39000.0   Delhi     22000.0  First Owner
# 32644       TVS Apache RTR 180cc  30000.0  Karnal      6639.0  First Owner
# 32645   Bajaj Avenger Street 220  60000.0   Delhi     20373.0  First Owner
# 32646  Hero Super Splendor 125cc  15600.0  Jaipur     84186.0  First Owner
# 32647         Bajaj Pulsar 150cc  22000.0    Pune     60857.0  First Owner
#
#         age  power  brand
# 32643   4.0  100.0   Hero
# 32644   9.0  180.0    TVS
# 32645   6.0  220.0  Bajaj
# 32646  16.0  125.0   Hero
# 32647  13.0  150.0  Bajaj

# %%
df.head(10)                             #for top 10 values
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# 5                          Yamaha FZs 150cc   53499.0      Delhi     25000.0
# 6             Honda CB Hornet 160R  ABS DLX   85000.0      Delhi      8200.0
# 7       Hero Splendor Plus Self Alloy 100cc   45000.0      Delhi     12645.0
# 8         Royal Enfield Thunderbird X 350cc  145000.0  Bangalore      9190.0
# 9  Royal Enfield Classic Desert Storm 500cc   88000.0      Delhi     19000.0
#
#           owner  age  power          brand
# 0   First Owner  3.0  110.0            TVS
# ...

# %%
df.tail(10)                       #for last top 10
# Out:
#                          bike_name     price         city  kms_driven  \
# 32638        Yamaha Fazer 25 250cc  123000.0       Kadapa     14500.0
# 32639  Royal Enfield Classic 350cc   95500.0        Delhi     18000.0
# 32640       Hero Passion Pro 100cc   32000.0        Delhi     12000.0
# 32641          Bajaj Avenger 220cc   41000.0        Delhi     20245.0
# 32642           Hero Passion 100cc   15000.0  Perumbavoor     35000.0
# 32643       Hero Passion Pro 100cc   39000.0        Delhi     22000.0
# 32644         TVS Apache RTR 180cc   30000.0       Karnal      6639.0
# 32645     Bajaj Avenger Street 220   60000.0        Delhi     20373.0
# 32646    Hero Super Splendor 125cc   15600.0       Jaipur     84186.0
# 32647           Bajaj Pulsar 150cc   22000.0         Pune     60857.0
#
#               owner   age  power          brand
# 32638   First Owner   4.0  250.0         Yamaha
# 32639   First Owner   8.0  350.0  Royal Enfield
# 32640   First Owner   6.0  100.0           Hero
# ...

# %%
df.duplicated().sum()                #for duplicate
# Out:
# 25324

# %%
df.info()                         #for knowing information about used_bikes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32648 entries, 0 to 32647
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   bike_name   32648 non-null  object
#  1   price       32648 non-null  float64
#  2   city        32648 non-null  object
#  3   kms_driven  32648 non-null  float64
#  4   owner       32648 non-null  object
#  5   age         32648 non-null  float64
#  6   power       32648 non-null  float64
#  7   brand       32648 non-null  object
# dtypes: float64(4), object(4)
# memory usage: 2.0+ MB

# %%
df['brand'].unique()                #for getting brands without repetition
# Out:
# array(['TVS', 'Royal Enfield', 'Triumph', 'Yamaha', 'Honda', 'Hero',
#        'Bajaj', 'Suzuki', 'Benelli', 'KTM', 'Mahindra', 'Kawasaki',
#        'Ducati', 'Hyosung', 'Harley-Davidson', 'Jawa', 'BMW', 'Indian',
#        'Rajdoot', 'LML', 'Yezdi', 'MV', 'Ideal'], dtype=object)

# %%
df['bike_name'].unique()                   #all bikename  but not repeated
# Out:
# array(['TVS Star City Plus Dual Tone 110cc',
#        'Royal Enfield Classic 350cc', 'Triumph Daytona 675R',
#        'TVS Apache RTR 180cc', 'Yamaha FZ S V 2.0 150cc-Ltd. Edition',
#        'Yamaha FZs 150cc', 'Honda CB Hornet 160R  ABS DLX',
#        'Hero Splendor Plus Self Alloy 100cc',
#        'Royal Enfield Thunderbird X 350cc',
#        'Royal Enfield Classic Desert Storm 500cc',
#        'Yamaha YZF-R15 2.0 150cc', 'Yamaha FZ25 250cc',
#        'Bajaj Pulsar NS200', 'Bajaj Discover 100M', 'Bajaj Discover 125M',
#        'Bajaj Pulsar NS200 ABS', 'Bajaj Pulsar RS200 ABS',
#        'Suzuki Gixxer SF 150cc', 'Benelli 302R 300CC',
#        'Hero Splendor iSmart Plus IBS 110cc',
#        'Royal Enfield Classic Chrome 500cc', 'Yamaha FZ V 2.0 150cc',
#        'Hero Super Splendor 125cc', 'Honda CBF Stunner 125cc',
#        'Bajaj Pulsar 150cc', 'Honda X-Blade 160CC ABS',
#        'Bajaj Avenger 220cc', 'KTM RC 390cc', 'Honda CB Unicorn 150cc',
# ...

# %%
df.isnull()                 #for null values
# Out:
#        bike_name  price   city  kms_driven  owner    age  power  brand
# 0          False  False  False       False  False  False  False  False
# 1          False  False  False       False  False  False  False  False
# 2          False  False  False       False  False  False  False  False
# 3          False  False  False       False  False  False  False  False
# 4          False  False  False       False  False  False  False  False
# ...          ...    ...    ...         ...    ...    ...    ...    ...
# 32643      False  False  False       False  False  False  False  False
# 32644      False  False  False       False  False  False  False  False
# 32645      False  False  False       False  False  False  False  False
# 32646      False  False  False       False  False  False  False  False
# 32647      False  False  False       False  False  False  False  False
#
# [32648 rows x 8 columns]

# %%
df.isnull().sum()                     #for null with sum
# Out:
# bike_name     0
# price         0
# city          0
# kms_driven    0
# owner         0
# age           0
# power         0
# brand         0
# dtype: int64

# %%
df_TVS=df[df['brand']=='TVS']                  #knowing details about TVS
df_TVS
# Out:
#                                 bike_name    price       city  kms_driven  \
# 0      TVS Star City Plus Dual Tone 110cc  35000.0  Ahmedabad     17654.0
# 3                    TVS Apache RTR 180cc  65000.0  Bangalore     16329.0
# 52                   TVS Apache RTR 160cc  60000.0     Mumbai     30000.0
# 114            TVS Apache RTR 160 4V Disc  69900.0      Delhi      8700.0
# 130                TVS Phoenix Disc 125cc  21500.0    Barasat     10500.0
# ...                                   ...      ...        ...         ...
# 32549                TVS Apache RTR 180cc  30000.0     Karnal      6639.0
# 32568                TVS Apache RTR 180cc  30000.0     Karnal      6639.0
# 32587                TVS Apache RTR 180cc  30000.0     Karnal      6639.0
# 32606                TVS Apache RTR 180cc  30000.0     Karnal      6639.0
# 32644                TVS Apache RTR 180cc  30000.0     Karnal      6639.0
#
#              owner  age  power brand
# 0      First Owner  3.0  110.0   TVS
# ...

# %%
df[df['brand']=='TVS']                  #brand = tvs
# Out:
#                                 bike_name    price       city  kms_driven  \
# 0      TVS Star City Plus Dual Tone 110cc  35000.0  Ahmedabad     17654.0
# 3                    TVS Apache RTR 180cc  65000.0  Bangalore     16329.0
# 52                   TVS Apache RTR 160cc  60000.0     Mumbai     30000.0
# 114            TVS Apache RTR 160 4V Disc  69900.0      Delhi      8700.0
# 130                TVS Phoenix Disc 125cc  21500.0    Barasat     10500.0
# ...                                   ...      ...        ...         ...
# 32549                TVS Apache RTR 180cc  30000.0     Karnal      6639.0
# 32568                TVS Apache RTR 180cc  30000.0     Karnal      6639.0
# 32587                TVS Apache RTR 180cc  30000.0     Karnal      6639.0
# 32606                TVS Apache RTR 180cc  30000.0     Karnal      6639.0
# 32644                TVS Apache RTR 180cc  30000.0     Karnal      6639.0
#
#              owner  age  power brand
# 0      First Owner  3.0  110.0   TVS
# ...

# %%
df_TVS1=df_TVS[df_TVS['price']<=50000]          #for price which is equal to or more than 50000 in TVS
df_TVS1
# Out:
#                                 bike_name    price       city  kms_driven  \
# 0      TVS Star City Plus Dual Tone 110cc  35000.0  Ahmedabad     17654.0
# 130                TVS Phoenix Disc 125cc  21500.0    Barasat     10500.0
# 131                  TVS Apache RTR 160cc  40000.0      Delhi     20000.0
# 215                   TVS Star City 110cc  28000.0  Bangalore     28428.0
# 235                       TVS Sport 100cc  28000.0      Mandi     36000.0
# ...                                   ...      ...        ...         ...
# 32549                TVS Apache RTR 180cc  30000.0     Karnal      6639.0
# 32568                TVS Apache RTR 180cc  30000.0     Karnal      6639.0
# 32587                TVS Apache RTR 180cc  30000.0     Karnal      6639.0
# 32606                TVS Apache RTR 180cc  30000.0     Karnal      6639.0
# 32644                TVS Apache RTR 180cc  30000.0     Karnal      6639.0
#
#              owner  age  power brand
# 0      First Owner  3.0  110.0   TVS
# ...

# %%
df_TVS1.duplicated()              #for duplicate values
# Out:
# 0        False
# 130      False
# 131      False
# 215      False
# 235      False
#          ...
# 32549     True
# 32568     True
# 32587     True
# 32606     True
# 32644     True
# Length: 936, dtype: bool

# %%
df['power'].unique()           #for knowing power but not repeated
# Out:
# array([ 110.,  350.,  675.,  180.,  150.,  160.,  100.,  500.,  250.,
#         200.,  125.,  302.,  220.,  390.,  600.,  900.,  650.,  223.,
#         410.,  135., 1100.,  765.,  300., 1299.,  750.,  400., 1300.,
#         821., 1198.,  883.,  959.,  295.,  320.,  310.,  899., 1800.,
#         535., 1130., 1000., 1200., 1050.,  800., 1262., 1700.,  175.,
#         865.,  797.,  796.,  149.,  850., 1090.,  502.,  107.])

# %%
df_TVS1.duplicated()        #for tvsdatatype with length
# Out:
# 0        False
# 130      False
# 131      False
# 215      False
# 235      False
#          ...
# 32549     True
# 32568     True
# 32587     True
# 32606     True
# 32644     True
# Length: 936, dtype: bool

# %%
df_TVS1.isnull().sum()                   #for null values of TVS with sum
# Out:
# bike_name     0
# price         0
# city          0
# kms_driven    0
# owner         0
# age           0
# power         0
# brand         0
# dtype: int64

# %%
df.isnull().sum()                     #for null values with sum
# Out:
# bike_name     0
# price         0
# city          0
# kms_driven    0
# owner         0
# age           0
# power         0
# brand         0
# dtype: int64

# %%
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
df.duplicated().sum()
# Out:
# 25324

# %%
df_TVS1=df_TVS[df_TVS['price']<30000]          #TVS1 price more than 30000
df_TVS1
# Out:
#                    bike_name    price       city  kms_driven         owner  \
# 130   TVS Phoenix Disc 125cc  21500.0    Barasat     10500.0   First Owner
# 215      TVS Star City 110cc  28000.0  Bangalore     28428.0   First Owner
# 235          TVS Sport 100cc  28000.0      Mandi     36000.0   First Owner
# 264          TVS Sport 100cc  28000.0      Mandi     36000.0   First Owner
# 374         TVS Apache 150cc   9350.0  Bangalore     39822.0  Second Owner
# ...                      ...      ...        ...         ...           ...
# 9143     TVS Star City 110cc  15000.0    Chennai     39888.0   First Owner
# 9155     TVS Star City 110cc  14000.0    Chennai     17602.0   First Owner
# 9158        TVS MAX 4R 110cc  18000.0    Chennai     13673.0   First Owner
# 9296     TVS Star City 110cc  20000.0   Palakkad     49500.0   First Owner
# 9320        TVS Apache 150cc  20000.0     Hissar     84916.0   First Owner
#
#        age  power brand
# 130    5.0  125.0   TVS
# ...

# %%
df_TVS.min()                       #for min value of TVS  details
# Out:
# bike_name     TVS Apache 150cc
# price                   5800.0
# city                    Adalaj
# kms_driven               100.0
# owner              First Owner
# age                        1.0
# power                    100.0
# brand                      TVS
# dtype: object

# %%
df_TVS.max()                  #for max value of TVS  details
# Out:
# bike_name     TVS Victor GX 110cc
# price                    224000.0
# city                Visakhapatnam
# kms_driven               266028.0
# owner                 Third Owner
# age                          23.0
# power                       310.0
# brand                         TVS
# dtype: object

# %%
df_TVS.describe()            # find all the details of the tvs bike
# Out:
#                price     kms_driven          age        power
# count    1247.000000    1247.000000  1247.000000  1247.000000
# mean    44299.146752   14717.836407     7.310345   170.994387
# std     32540.843696   18193.866096     2.928919    35.771333
# min      5800.000000     100.000000     1.000000   100.000000
# 25%     30000.000000    6639.000000     5.000000   160.000000
# 50%     30000.000000    6639.000000     9.000000   180.000000
# 75%     50000.000000   18477.000000     9.000000   180.000000
# max    224000.000000  266028.000000    23.000000   310.000000

# %%
df_TVS['price'].mean()                ## finding the average
# Out:
# 44299.14675220529

# %%
#question 1
#Royal_Enfield
#age = 2
# distance 50km
#price = 1lakh
df_RE=df[df['brand']=='Royal Enfield']
df_RE
# Out:
#                                       bike_name     price  \
# 1                   Royal Enfield Classic 350cc  119900.0
# 8             Royal Enfield Thunderbird X 350cc  145000.0
# 9      Royal Enfield Classic Desert Storm 500cc   88000.0
# 23           Royal Enfield Classic Chrome 500cc  121700.0
# 36                  Royal Enfield Classic 350cc   98800.0
# ...                                         ...       ...
# 32601               Royal Enfield Classic 350cc   95500.0
# 32614        Royal Enfield Bullet Electra 350cc  105000.0
# 32633               Royal Enfield Classic 350cc   87000.0
# 32634           Royal Enfield Thunderbird 350cc   70000.0
# 32639               Royal Enfield Classic 350cc   95500.0
#
#                       city  kms_driven         owner   age  power  \
# 1                    Delhi     11000.0   First Owner   4.0  350.0
# 8                Bangalore      9190.0   First Owner   3.0  350.0
# 9                    Delhi     19000.0  Second Owner   7.0  500.0
# ...

# %%
#question 2
#bike name = Royal Enfield Classic Desert Storm 500cc
# owner = 'First Owner'
# city = "Delhi"
# power = '500.0'
# price = '2lakh'
# age = '5years
df_RE3=df_RE[df_RE['bike_name']=='Royal Enfield Classic Desert Storm 500cc']
df_RE3
# Out:
#                                      bike_name     price        city  \
# 9     Royal Enfield Classic Desert Storm 500cc   88000.0       Delhi
# 192   Royal Enfield Classic Desert Storm 500cc  110800.0      Mumbai
# 1299  Royal Enfield Classic Desert Storm 500cc  130000.0   Ahmedabad
# 1452  Royal Enfield Classic Desert Storm 500cc  175000.0        Pune
# 1531  Royal Enfield Classic Desert Storm 500cc   95000.0   Bangalore
# 2091  Royal Enfield Classic Desert Storm 500cc  140000.0    Godavari
# 2148  Royal Enfield Classic Desert Storm 500cc  135000.0     Gurgaon
# 2486  Royal Enfield Classic Desert Storm 500cc  132100.0     Chennai
# 2520  Royal Enfield Classic Desert Storm 500cc  100000.0     Chennai
# 2812  Royal Enfield Classic Desert Storm 500cc  110000.0     Chennai
# 2934  Royal Enfield Classic Desert Storm 500cc   90000.0     Gurgaon
# 3189  Royal Enfield Classic Desert Storm 500cc  130000.0   Bangalore
# 3190  Royal Enfield Classic Desert Storm 500cc  200000.0   Bangalore
# ...

# %%
#for first owner
df_RE4=df_RE3[df_RE3['owner']=='First Owner']
df_RE4
# Out:
#                                      bike_name     price        city  \
# 192   Royal Enfield Classic Desert Storm 500cc  110800.0      Mumbai
# 1299  Royal Enfield Classic Desert Storm 500cc  130000.0   Ahmedabad
# 1452  Royal Enfield Classic Desert Storm 500cc  175000.0        Pune
# 1531  Royal Enfield Classic Desert Storm 500cc   95000.0   Bangalore
# 2091  Royal Enfield Classic Desert Storm 500cc  140000.0    Godavari
# 2486  Royal Enfield Classic Desert Storm 500cc  132100.0     Chennai
# 2520  Royal Enfield Classic Desert Storm 500cc  100000.0     Chennai
# 2812  Royal Enfield Classic Desert Storm 500cc  110000.0     Chennai
# 2934  Royal Enfield Classic Desert Storm 500cc   90000.0     Gurgaon
# 3189  Royal Enfield Classic Desert Storm 500cc  130000.0   Bangalore
# 3190  Royal Enfield Classic Desert Storm 500cc  200000.0   Bangalore
# 3379  Royal Enfield Classic Desert Storm 500cc  110000.0     Chennai
# 3477  Royal Enfield Classic Desert Storm 500cc  132100.0     Chennai
# ...

# %%
#for city = Delhi
df_RE5=df_RE4[df_RE4['city']=='Delhi']
df_RE5
# Out:
#                                      bike_name     price   city  kms_driven  \
# 4032  Royal Enfield Classic Desert Storm 500cc  118000.0  Delhi      8000.0
# 4345  Royal Enfield Classic Desert Storm 500cc   98100.0  Delhi     17000.0
# 4462  Royal Enfield Classic Desert Storm 500cc   98100.0  Delhi     17000.0
# 5195  Royal Enfield Classic Desert Storm 500cc  119000.0  Delhi     14735.0
# 5455  Royal Enfield Classic Desert Storm 500cc  119000.0  Delhi     14735.0
# 6024  Royal Enfield Classic Desert Storm 500cc  110000.0  Delhi      6500.0
# 8246  Royal Enfield Classic Desert Storm 500cc  108400.0  Delhi      3545.0
# 9241  Royal Enfield Classic Desert Storm 500cc  140000.0  Delhi      8500.0
#
#             owner  age  power          brand
# 4032  First Owner  6.0  500.0  Royal Enfield
# 4345  First Owner  7.0  500.0  Royal Enfield
# 4462  First Owner  7.0  500.0  Royal Enfield
# 5195  First Owner  5.0  500.0  Royal Enfield
# 5455  First Owner  5.0  500.0  Royal Enfield
# ...

# %%
#for power
df_RE6=df_RE5[df_RE5['power']==500]
df_RE6
# Out:
#                                      bike_name     price   city  kms_driven  \
# 4032  Royal Enfield Classic Desert Storm 500cc  118000.0  Delhi      8000.0
# 4345  Royal Enfield Classic Desert Storm 500cc   98100.0  Delhi     17000.0
# 4462  Royal Enfield Classic Desert Storm 500cc   98100.0  Delhi     17000.0
# 5195  Royal Enfield Classic Desert Storm 500cc  119000.0  Delhi     14735.0
# 5455  Royal Enfield Classic Desert Storm 500cc  119000.0  Delhi     14735.0
# 6024  Royal Enfield Classic Desert Storm 500cc  110000.0  Delhi      6500.0
# 8246  Royal Enfield Classic Desert Storm 500cc  108400.0  Delhi      3545.0
# 9241  Royal Enfield Classic Desert Storm 500cc  140000.0  Delhi      8500.0
#
#             owner  age  power          brand
# 4032  First Owner  6.0  500.0  Royal Enfield
# 4345  First Owner  7.0  500.0  Royal Enfield
# 4462  First Owner  7.0  500.0  Royal Enfield
# 5195  First Owner  5.0  500.0  Royal Enfield
# 5455  First Owner  5.0  500.0  Royal Enfield
# ...

# %%
#for price
df_RE7=df_RE6[df_RE6['price']<=200000]
df_RE7
# Out:
#                                      bike_name     price   city  kms_driven  \
# 4032  Royal Enfield Classic Desert Storm 500cc  118000.0  Delhi      8000.0
# 4345  Royal Enfield Classic Desert Storm 500cc   98100.0  Delhi     17000.0
# 4462  Royal Enfield Classic Desert Storm 500cc   98100.0  Delhi     17000.0
# 5195  Royal Enfield Classic Desert Storm 500cc  119000.0  Delhi     14735.0
# 5455  Royal Enfield Classic Desert Storm 500cc  119000.0  Delhi     14735.0
# 6024  Royal Enfield Classic Desert Storm 500cc  110000.0  Delhi      6500.0
# 8246  Royal Enfield Classic Desert Storm 500cc  108400.0  Delhi      3545.0
# 9241  Royal Enfield Classic Desert Storm 500cc  140000.0  Delhi      8500.0
#
#             owner  age  power          brand
# 4032  First Owner  6.0  500.0  Royal Enfield
# 4345  First Owner  7.0  500.0  Royal Enfield
# 4462  First Owner  7.0  500.0  Royal Enfield
# 5195  First Owner  5.0  500.0  Royal Enfield
# 5455  First Owner  5.0  500.0  Royal Enfield
# ...

# %%
#for age
df_RE8=df_RE7[df_RE7['age']==5]
df_RE8
# Out:
#                                      bike_name     price   city  kms_driven  \
# 5195  Royal Enfield Classic Desert Storm 500cc  119000.0  Delhi     14735.0
# 5455  Royal Enfield Classic Desert Storm 500cc  119000.0  Delhi     14735.0
# 9241  Royal Enfield Classic Desert Storm 500cc  140000.0  Delhi      8500.0
#
#             owner  age  power          brand
# 5195  First Owner  5.0  500.0  Royal Enfield
# 5455  First Owner  5.0  500.0  Royal Enfield
# 9241  First Owner  5.0  500.0  Royal Enfield

# %%
#for price
df_RE1=df_RE[df_RE['price']>=100000]
df_RE1
# Out:
#                                 bike_name     price        city  kms_driven  \
# 1             Royal Enfield Classic 350cc  119900.0       Delhi     11000.0
# 8       Royal Enfield Thunderbird X 350cc  145000.0   Bangalore      9190.0
# 23     Royal Enfield Classic Chrome 500cc  121700.0      Kalyan     24520.0
# 38      Royal Enfield Thunderbird X 500cc  190500.0  Samastipur      4550.0
# 62     Royal Enfield Bullet Electra 350cc  107100.0       Delhi     15438.0
# ...                                   ...       ...         ...         ...
# 32348  Royal Enfield Bullet Electra 350cc  105000.0       Delhi     20000.0
# 32367  Royal Enfield Bullet Electra 350cc  105000.0       Delhi     20000.0
# 32443  Royal Enfield Bullet Electra 350cc  105000.0       Delhi     20000.0
# 32481  Royal Enfield Bullet Electra 350cc  105000.0       Delhi     20000.0
# 32614  Royal Enfield Bullet Electra 350cc  105000.0       Delhi     20000.0
#
#               owner  age  power          brand
# ...

# %%
ub_df_royal_enfield_classic = df[(df['owner'] == 'First Owner') &             #for printing together
                                 (df['city'] == 'Delhi') &
                                 (df['power'] > 500.0) &
                                 (df['price'] > 200000)]

# %%
ub_df_royal_enfield_classic
# Out:
#                        bike_name     price   city  kms_driven        owner  \
# 2           Triumph Daytona 675R  600000.0  Delhi       110.0  First Owner
# 110               Hyosung GT650R  400000.0  Delhi      1800.0  First Owner
# 228          Ducati Panigale 959  885000.0  Delhi       300.0  First Owner
# 565   Harley-Davidson Street 750  350000.0  Delhi      5000.0  First Owner
# 582   Harley-Davidson Street 750  350000.0  Delhi      5000.0  First Owner
# ...                          ...       ...    ...         ...          ...
# 7997  Harley-Davidson Street 750  478000.0  Delhi      1300.0  First Owner
# 8446  Harley-Davidson Street 750  406600.0  Delhi     10196.0  First Owner
# 8637   Honda CBR1000RR Fireblade  799000.0  Delhi     15000.0  First Owner
# 8747    Harley-Davidson Iron 883  650000.0  Delhi      1900.0  First Owner
# 9266  Harley-Davidson Street 750  478000.0  Delhi      1300.0  First Owner
#
#        age   power            brand
# ...

# %%
ub_df_royal_enfield_classic
# Out:
#                        bike_name     price   city  kms_driven        owner  \
# 2           Triumph Daytona 675R  600000.0  Delhi       110.0  First Owner
# 110               Hyosung GT650R  400000.0  Delhi      1800.0  First Owner
# 228          Ducati Panigale 959  885000.0  Delhi       300.0  First Owner
# 565   Harley-Davidson Street 750  350000.0  Delhi      5000.0  First Owner
# 582   Harley-Davidson Street 750  350000.0  Delhi      5000.0  First Owner
# ...                          ...       ...    ...         ...          ...
# 7997  Harley-Davidson Street 750  478000.0  Delhi      1300.0  First Owner
# 8446  Harley-Davidson Street 750  406600.0  Delhi     10196.0  First Owner
# 8637   Honda CBR1000RR Fireblade  799000.0  Delhi     15000.0  First Owner
# 8747    Harley-Davidson Iron 883  650000.0  Delhi      1900.0  First Owner
# 9266  Harley-Davidson Street 750  478000.0  Delhi      1300.0  First Owner
#
#        age   power            brand
# ...

# %%
df_RE2=df_RE1[df_RE1['kms_driven']<=50.0]
df_RE2
# Out:
#                                bike_name     price       city  kms_driven  \
# 3523  Royal Enfield Bullet Electra 350cc  112200.0  Bangalore        40.0
#
#             owner  age  power          brand
# 3523  First Owner  7.0  350.0  Royal Enfield

# %%
df_RE2[df_RE2['age']==2]
# Out:
# Empty DataFrame
# Columns: [bike_name, price, city, kms_driven, owner, age, power, brand]
# Index: []

# %%
df['age'].unique()
# Out:
# array([ 3.,  4.,  8.,  6.,  7.,  5.,  2., 16., 13.,  9., 10., 14., 12.,
#        11.,  1., 15., 39., 17., 18., 30., 19., 23., 41., 27., 37., 24.,
#        20., 43., 38., 63., 34., 31., 22., 26., 25.])

# %%
df['brand'].unique()
# Out:
# array(['TVS', 'Royal Enfield', 'Triumph', 'Yamaha', 'Honda', 'Hero',
#        'Bajaj', 'Suzuki', 'Benelli', 'KTM', 'Mahindra', 'Kawasaki',
#        'Ducati', 'Hyosung', 'Harley-Davidson', 'Jawa', 'BMW', 'Indian',
#        'Rajdoot', 'LML', 'Yezdi', 'MV', 'Ideal'], dtype=object)

# %%
df['bike_name'].unique()
# Out:
# array(['TVS Star City Plus Dual Tone 110cc',
#        'Royal Enfield Classic 350cc', 'Triumph Daytona 675R',
#        'TVS Apache RTR 180cc', 'Yamaha FZ S V 2.0 150cc-Ltd. Edition',
#        'Yamaha FZs 150cc', 'Honda CB Hornet 160R  ABS DLX',
#        'Hero Splendor Plus Self Alloy 100cc',
#        'Royal Enfield Thunderbird X 350cc',
#        'Royal Enfield Classic Desert Storm 500cc',
#        'Yamaha YZF-R15 2.0 150cc', 'Yamaha FZ25 250cc',
#        'Bajaj Pulsar NS200', 'Bajaj Discover 100M', 'Bajaj Discover 125M',
#        'Bajaj Pulsar NS200 ABS', 'Bajaj Pulsar RS200 ABS',
#        'Suzuki Gixxer SF 150cc', 'Benelli 302R 300CC',
#        'Hero Splendor iSmart Plus IBS 110cc',
#        'Royal Enfield Classic Chrome 500cc', 'Yamaha FZ V 2.0 150cc',
#        'Hero Super Splendor 125cc', 'Honda CBF Stunner 125cc',
#        'Bajaj Pulsar 150cc', 'Honda X-Blade 160CC ABS',
#        'Bajaj Avenger 220cc', 'KTM RC 390cc', 'Honda CB Unicorn 150cc',
# ...

# %%
ub_df_royal_enfield_classic = df[(df['owner'] == 'Second Owner') &
                                 (df['city'] == 'Delhi') &
                                 (df['age'] <= 3) &
                                 (df['price'] <= 100000)]
ub_df_royal_enfield_classic
# Out:
#                                             bike_name    price   city  \
# 1863                       TVS Apache RTR 160 4V Disc  65000.0  Delhi
# 2103                       TVS Apache RTR 160 4V Disc  65000.0  Delhi
# 2143                             TVS Apache RTR 180cc  70000.0  Delhi
# 3807                               Bajaj Pulsar NS160  70000.0  Delhi
# 4023           TVS Apache RTR 200 4V ABS Race Edition  85000.0  Delhi
# 4252                           Suzuki Hayate EP 110cc  22950.0  Delhi
# 5364                             TVS Apache RTR 180cc  72000.0  Delhi
# 5710                             TVS Apache RTR 180cc  72000.0  Delhi
# 6610  TVS Apache RTR 160 4V Carburetor With Rear Disc  80000.0  Delhi
#
#       kms_driven         owner  age  power   brand
# 1863     10000.0  Second Owner  3.0  160.0     TVS
# 2103     10000.0  Second Owner  3.0  160.0     TVS
# 2143      7000.0  Second Owner  3.0  180.0     TVS
# 3807     16880.0  Second Owner  2.0  160.0   Bajaj
# ...

# %%
#question 3
# brand= royal
# #price = 100000+
# age = 3year+
# price min or max
# total bike

ub_df_royal_enfield_classic = df[(df['brand']=='KTM')&
                                (df['owner'] == 'Second Owner') &
                                (df['price'] >= 100000) &
                                (df['age'] >= 3)|
                                (df['brand']=='Royal Enfield')&
                                (df['owner']=='Second Owner')&
                                (df['price']>=100000)&
                                (df['age']>=3)]
ub_df_royal_enfield_classic
# Out:
#                                      bike_name     price        city  \
# 62          Royal Enfield Bullet Electra 350cc  107100.0       Delhi
# 83                              KTM Duke 250cc  130000.0  Gandhidham
# 173                               KTM RC 200cc  118000.0       Delhi
# 406                Royal Enfield Classic 350cc  115000.0       Delhi
# 418                Royal Enfield Classic 350cc  115000.0       Delhi
# ...                                        ...       ...         ...
# 8823  Royal Enfield Classic Desert Storm 500cc  105000.0     Chennai
# 9185     Royal Enfield Classic 500cc Dual Disc  163500.0    Azamgarh
# 9196               Royal Enfield Classic 500cc  116900.0        Pune
# 9303               Royal Enfield Classic 500cc  116900.0        Pune
# 9308     Royal Enfield Classic 500cc Dual Disc  163500.0    Azamgarh
#
#       kms_driven         owner  age  power          brand
# 62       15438.0  Second Owner  3.0  350.0  Royal Enfield
# ...

# %%
df_RE.describe()
# Out:
#                price     kms_driven          age        power
# count    4178.000000    4178.000000  4178.000000  4178.000000
# mean    98562.072044   18275.558640     7.095261   366.104596
# std     25853.300790   13344.771142     3.600338    47.263840
# min     33500.000000      40.000000     2.000000   350.000000
# 25%     87000.000000   13858.000000     4.000000   350.000000
# 50%     95500.000000   16336.000000     7.000000   350.000000
# 75%    105000.000000   20000.000000     8.000000   350.000000
# max    285000.000000  300965.000000    63.000000   650.000000

# %%
df_RE.min()
# Out:
# bike_name     Royal Enfield Bullet 350 cc
# price                             33500.0
# city                           24 Pargana
# kms_driven                           40.0
# owner                         First Owner
# age                                   2.0
# power                               350.0
# brand                       Royal Enfield
# dtype: object

# %%
df_RE.max()
# Out:
# bike_name     Royal Enfield‎ Bullet 350cc
# price                            285000.0
# city                             Warangal
# kms_driven                       300965.0
# owner                         Third Owner
# age                                  63.0
# power                               650.0
# brand                       Royal Enfield
# dtype: object

# %%
df_RE=df[df['brand']=='Royal Enfield']
df_RE
# Out:
#                                       bike_name     price  \
# 1                   Royal Enfield Classic 350cc  119900.0
# 8             Royal Enfield Thunderbird X 350cc  145000.0
# 9      Royal Enfield Classic Desert Storm 500cc   88000.0
# 23           Royal Enfield Classic Chrome 500cc  121700.0
# 36                  Royal Enfield Classic 350cc   98800.0
# ...                                         ...       ...
# 32601               Royal Enfield Classic 350cc   95500.0
# 32614        Royal Enfield Bullet Electra 350cc  105000.0
# 32633               Royal Enfield Classic 350cc   87000.0
# 32634           Royal Enfield Thunderbird 350cc   70000.0
# 32639               Royal Enfield Classic 350cc   95500.0
#
#                       city  kms_driven         owner   age  power  \
# 1                    Delhi     11000.0   First Owner   4.0  350.0
# 8                Bangalore      9190.0   First Owner   3.0  350.0
# 9                    Delhi     19000.0  Second Owner   7.0  500.0
# ...

# %%
df_KR['brand'].unique()
# Out:
# array(['Royal Enfield', 'KTM'], dtype=object)

# %%
df_KR.min()
# Out:
# bike_name     KTM Duke 200cc
# price               100000.0
# city               Ahmedabad
# kms_driven            1400.0
# owner           Second Owner
# age                      3.0
# power                  200.0
# brand                    KTM
# dtype: object

# %%
df_KR.max()
# Out:
# bike_name     Royal Enfield Thunderbird X 500cc
# price                                  860000.0
# city                               Vizianagaram
# kms_driven                              48000.0
# owner                              Second Owner
# age                                        27.0
# power                                     535.0
# brand                             Royal Enfield
# dtype: object

# %%
df_KR.describe()
# Out:
#                price    kms_driven        age       power
# count      61.000000     61.000000  61.000000   61.000000
# mean   145401.606557  16875.426230   5.901639  405.573770
# std     99296.566863   9352.078759   3.414210   93.001337
# min    100000.000000   1400.000000   3.000000  200.000000
# 25%    115000.000000  11200.000000   5.000000  350.000000
# 50%    125000.000000  15000.000000   5.000000  390.000000
# 75%    140000.000000  21000.000000   6.000000  500.000000
# max    860000.000000  48000.000000  27.000000  535.000000
