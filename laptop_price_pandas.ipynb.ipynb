# %% [markdown]
# # -->Pandas
# #### pandas is a python library.
# #### pandas used to analyze data.

# %% [markdown]
# what is Pandas?
# * Pandas ia a python library used for working with data sets.
# * it has functions for analyzing, cleaning, exporing,and manipulating data.

# %%
import pandas as pd

# %%
mydataset = {
    'cars': ["BMW","Volve","Ford"],                         #set of cars and their passing no.
    'passing': [3, 7, 2]
}
mydataset
df=pd.DataFrame(mydataset)
df
# Out:
#     cars  passing
# 0    BMW        3
# 1  Volve        7
# 2   Ford        2

# %%
pd.__version__                         #version of panda
# Out:
# '2.2.2'

# %%
lp_df=pd.read_csv('laptopPrice.csv')         
lp_df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
lp_df.isnull()                       #determin that its nul or not
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 0    False            False           False            False   False
# 1    False            False           False            False   False
# 2    False            False           False            False   False
# 3    False            False           False            False   False
# 4    False            False           False            False   False
# ..     ...              ...             ...              ...     ...
# 818  False            False           False            False   False
# 819  False            False           False            False   False
# 820  False            False           False            False   False
# 821  False            False           False            False   False
# 822  False            False           False            False   False
#
#      ram_type    ssd    hdd     os  os_bit  graphic_card_gb  weight  warranty  \
# ...

# %%
lp_df.isnull().sum()                                  #name of column
# Out:
# brand                0
# processor_brand      0
# processor_name       0
# processor_gnrtn      0
# ram_gb               0
# ram_type             0
# ssd                  0
# hdd                  0
# os                   0
# os_bit               0
# graphic_card_gb      0
# weight               0
# warranty             0
# Touchscreen          0
# msoffice             0
# Price                0
# rating               0
# Number of Ratings    0
# Number of Reviews    0
# dtype: int64

# %%
lp_df.duplicated()                                            #for to see duplicates function(means length)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 818    False
# 819    False
# 820    False
# 821    False
# 822    False
# Length: 823, dtype: bool

# %%
lp_df.duplicated().sum()                                 #show total no. of duplications of row column
# Out:
# 21

# %%
lp_df.info()                          #give the information about laptop price(column,count(null value or not),datatype)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 823 entries, 0 to 822
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   brand              823 non-null    object
#  1   processor_brand    823 non-null    object
#  2   processor_name     823 non-null    object
#  3   processor_gnrtn    823 non-null    object
#  4   ram_gb             823 non-null    object
#  5   ram_type           823 non-null    object
#  6   ssd                823 non-null    object
#  7   hdd                823 non-null    object
#  8   os                 823 non-null    object
#  9   os_bit             823 non-null    object
#  10  graphic_card_gb    823 non-null    object
#  11  weight             823 non-null    object
#  12  warranty           823 non-null    object
#  13  Touchscreen        823 non-null    object
#  14  msoffice           823 non-null    object
#  15  Price              823 non-null    int64
# ...

# %%
lp_df['brand']                     #give name of brand but it repeat also
# Out:
# 0        ASUS
# 1      Lenovo
# 2      Lenovo
# 3        ASUS
# 4        ASUS
#         ...
# 818      ASUS
# 819      ASUS
# 820      ASUS
# 821      ASUS
# 822    Lenovo
# Name: brand, Length: 823, dtype: object

# %%
lp_df['brand'].unique()                 #give name of brand in unique not repeat it
# Out:
# array(['ASUS', 'Lenovo', 'acer', 'Avita', 'HP', 'DELL', 'MSI', 'APPLE'],
#       dtype=object)

# %%
lp_df['processor_brand']            #give the processor name of laptop price
# Out:
# 0      Intel
# 1      Intel
# 2      Intel
# 3      Intel
# 4      Intel
#        ...
# 818      AMD
# 819      AMD
# 820      AMD
# 821      AMD
# 822      AMD
# Name: processor_brand, Length: 823, dtype: object

# %%
lp_df['Touchscreen']            #give the touchscreen
# Out:
# 0      No
# 1      No
# 2      No
# 3      No
# 4      No
#        ..
# 818    No
# 819    No
# 820    No
# 821    No
# 822    No
# Name: Touchscreen, Length: 823, dtype: object

# %%
lp_df['Touchscreen'].unique()                   #give the touchscreen with unique
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
lp_df['msoffice'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
lp_df['ssd']                                #give the ssd
# Out:
# 0         0 GB
# 1         0 GB
# 2         0 GB
# 3       512 GB
# 4         0 GB
#         ...
# 818    1024 GB
# 819    1024 GB
# 820    1024 GB
# 821    1024 GB
# 822     512 GB
# Name: ssd, Length: 823, dtype: object

# %%
lp_df['ssd'].unique()           #give the unique ssd not repeated
# Out:
# array(['0 GB', '512 GB', '256 GB', '128 GB', '1024 GB', '2048 GB',
#        '3072 GB'], dtype=object)

# %%
lp_df['weight']             #give the weight
# Out:
# 0          Casual
# 1          Casual
# 2          Casual
# 3          Casual
# 4          Casual
#           ...
# 818        Casual
# 819        Casual
# 820        Casual
# 821        Casual
# 822    ThinNlight
# Name: weight, Length: 823, dtype: object

# %%
lp_df_apple=lp_df[lp_df['brand']=='APPLE']      #show how much the apple brand here
lp_df_apple
# Out:
#      brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 309  APPLE           Intel        Core i5            10th   8 GB  LPDDR4X
# 310  APPLE           Intel        Core i5             8th   8 GB     DDR3
# 407  APPLE           Intel        Core i5            10th  16 GB  LPDDR4X
# 408  APPLE           Intel        Core i5            10th  16 GB  LPDDR4X
# 599  APPLE              M1             M1            10th   8 GB     DDR4
# 600  APPLE              M1             M1            10th   8 GB     DDR4
# 601  APPLE              M1             M1            10th  16 GB     DDR4
# 602  APPLE              M1             M1            10th   8 GB     DDR4
# 603  APPLE              M1             M1            10th  16 GB     DDR4
# 604  APPLE              M1             M1            10th  16 GB     DDR4
# 605  APPLE              M1             M1            10th   8 GB     DDR4
# 606  APPLE              M1             M1            10th  16 GB     DDR4
# ...

# %%
lp_df_apple[lp_df_apple['Price']<100000]        #here price is less than 100000
# Out:
#      brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 599  APPLE              M1             M1            10th   8 GB     DDR4
# 605  APPLE              M1             M1            10th   8 GB     DDR4
#
#         ssd   hdd   os  os_bit graphic_card_gb  weight warranty Touchscreen  \
# 599  256 GB  0 GB  Mac  64-bit            0 GB  Casual   1 year          No
# 605  256 GB  0 GB  Mac  64-bit            0 GB  Casual   1 year          No
#
#     msoffice  Price   rating  Number of Ratings  Number of Reviews
# 599       No  85990  4 stars               6725                629
# 605       No  85990  4 stars               6725                629

# %%
lp_df['brand'].unique()         #give the unique brand not repeated
# Out:
# array(['ASUS', 'Lenovo', 'acer', 'Avita', 'HP', 'DELL', 'MSI', 'APPLE'],
#       dtype=object)

# %%
lp_df_apple.sum()                  #detail fo apple with sum
# Out:
# brand                APPLEAPPLEAPPLEAPPLEAPPLEAPPLEAPPLEAPPLEAPPLEA...
# processor_brand      IntelIntelIntelIntelM1M1M1M1M1M1M1M1M1M1M1M1M1...
# processor_name       Core i5Core i5Core i5Core i5M1M1M1M1M1M1M1M1M1...
# processor_gnrtn      10th8th10th10th10th10th10th10th10th10th10th10t...
# ram_gb               8 GB8 GB16 GB16 GB8 GB8 GB16 GB8 GB16 GB16 GB8...
# ram_type             LPDDR4XDDR3LPDDR4XLPDDR4XDDR4DDR4DDR4DDR4DDR4D...
# ssd                  512 GB512 GB1024 GB1024 GB256 GB256 GB256 GB25...
# hdd                  0 GB0 GB0 GB0 GB0 GB0 GB0 GB0 GB0 GB0 GB0 GB0 ...
# os                   MacMacMacMacMacMacMacMacMacMacMacMacMacMacMacM...
# os_bit               64-bit64-bit64-bit64-bit64-bit64-bit64-bit64-b...
# graphic_card_gb      0 GB0 GB0 GB0 GB0 GB0 GB0 GB0 GB0 GB0 GB0 GB0 ...
# weight               CasualCasualCasualCasualCasualCasualCasualCasu...
# warranty             1 year1 year1 year1 year1 year1 year1 year1 ye...
# ...

# %%
lp_df_hp=lp_df[lp_df['brand']=='HP']          #brand = HP
lp_df_hp
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 15     HP           Intel        Core i3            11th   8 GB     DDR4
# 16     HP           Intel        Core i5            11th   8 GB     DDR4
# 18     HP           Intel   Celeron Dual   Not Available   8 GB     DDR4
# 22     HP           Intel        Core i3             7th   4 GB     DDR4
# 23     HP           Intel        Core i5             7th   4 GB     DDR4
# ..    ...             ...            ...             ...    ...      ...
# 776    HP             AMD        Ryzen 7   Not Available  16 GB     DDR4
# 777    HP             AMD        Ryzen 7   Not Available  16 GB     DDR4
# 782    HP             AMD        Ryzen 7   Not Available   4 GB     DDR4
# 792    HP             AMD        Ryzen 7   Not Available  16 GB     DDR4
# 807    HP             AMD        Ryzen 9   Not Available   4 GB     DDR4
#
#          ssd      hdd       os  os_bit graphic_card_gb      weight  \
# ...

# %%
lp_df_hp1=lp_df_hp[lp_df_hp['processor_brand']=='Intel']             #getting processor brand hp 
lp_df_hp1
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 15     HP           Intel        Core i3            11th   8 GB     DDR4
# 16     HP           Intel        Core i5            11th   8 GB     DDR4
# 18     HP           Intel   Celeron Dual   Not Available   8 GB     DDR4
# 22     HP           Intel        Core i3             7th   4 GB     DDR4
# 23     HP           Intel        Core i5             7th   4 GB     DDR4
# ..    ...             ...            ...             ...    ...      ...
# 569    HP           Intel        Core i7            11th  16 GB  LPDDR4X
# 572    HP           Intel        Core i7            11th  16 GB     DDR4
# 573    HP           Intel        Core i7            11th  16 GB     DDR4
# 578    HP           Intel        Core i7             8th  16 GB     DDR4
# 626    HP           Intel   Pentium Quad   Not Available   8 GB     DDR4
#
#          ssd      hdd       os  os_bit graphic_card_gb      weight  \
# ...

# %%
lp_df_hp.sum()         #sum of hp
# Out:
# brand                HPHPHPHPHPHPHPHPHPHPHPHPHPHPHPHPHPHPHPHPHPHPHP...
# processor_brand      IntelIntelIntelIntelIntelIntelIntelIntelIntelI...
# processor_name       Core i3Core i5Celeron DualCore i3Core i5Core i...
# processor_gnrtn      11th11thNot Available7th7th11th11th11th11th11t...
# ram_gb               8 GB8 GB8 GB4 GB4 GB8 GB8 GB4 GB4 GB4 GB4 GB8 ...
# ram_type             DDR4DDR4DDR4DDR4DDR4DDR4DDR4DDR4DDR4DDR4DDR4DD...
# ssd                  256 GB256 GB256 GB0 GB0 GB256 GB256 GB256 GB25...
# hdd                  0 GB0 GB0 GB1024 GB1024 GB0 GB0 GB0 GB0 GB0 GB...
# os                   WindowsWindowsWindowsWindowsWindowsWindowsWind...
# os_bit               64-bit64-bit64-bit64-bit32-bit64-bit64-bit64-b...
# graphic_card_gb      0 GB0 GB0 GB0 GB2 GB0 GB0 GB0 GB0 GB0 GB0 GB0 ...
# weight               CasualCasualThinNlightCasualCasualThinNlightCa...
# warranty             1 year1 yearNo warrantyNo warrantyNo warranty1...
# ...

# %%
lp_df_hp2=lp_df_hp1[lp_df_hp1['Price']<=50000]      #price of hp2 is more than equal to 50000
lp_df_hp2
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 18     HP           Intel   Celeron Dual   Not Available   8 GB     DDR4
# 22     HP           Intel        Core i3             7th   4 GB     DDR4
# 23     HP           Intel        Core i5             7th   4 GB     DDR4
# 28     HP           Intel        Core i3            11th   8 GB     DDR4
# 57     HP           Intel        Core i3            11th   4 GB     DDR4
# 72     HP           Intel        Core i3            11th   4 GB     DDR4
# 75     HP           Intel        Core i3            11th   4 GB     DDR4
# 87     HP           Intel        Core i3            11th   8 GB     DDR4
# 88     HP           Intel        Core i3            11th   8 GB     DDR4
# 96     HP           Intel        Core i3            10th   8 GB     DDR4
# 97     HP           Intel        Core i3            11th   8 GB     DDR4
# 105    HP           Intel        Core i3            11th   8 GB     DDR4
# ...

# %%
lp_df_hp2.value_counts().sum()      #knowing value count of hp2
# Out:
# 31

# %%
lp_df_apple1=lp_df_apple[lp_df_apple['processor_brand']=='M1']          #in apple getting the processor brand == M1
lp_df_apple1
# Out:
#      brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 599  APPLE              M1             M1            10th   8 GB     DDR4
# 600  APPLE              M1             M1            10th   8 GB     DDR4
# 601  APPLE              M1             M1            10th  16 GB     DDR4
# 602  APPLE              M1             M1            10th   8 GB     DDR4
# 603  APPLE              M1             M1            10th  16 GB     DDR4
# 604  APPLE              M1             M1            10th  16 GB     DDR4
# 605  APPLE              M1             M1            10th   8 GB     DDR4
# 606  APPLE              M1             M1            10th  16 GB     DDR4
# 607  APPLE              M1             M1            10th   8 GB     DDR4
# 608  APPLE              M1             M1            10th   8 GB     DDR4
# 609  APPLE              M1             M1            10th   8 GB     DDR4
# 610  APPLE              M1             M1            10th   8 GB     DDR4
# ...

# %%
lp_df_apple2=lp_df_apple1[lp_df_apple1['Price']>=150000]        #price of apple is less than 150000
lp_df_apple2
# Out:
#      brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 613  APPLE              M1             M1            10th  16 GB     DDR4
# 614  APPLE              M1             M1            10th  16 GB     DDR4
# 618  APPLE              M1             M1            10th  16 GB     DDR4
# 619  APPLE              M1             M1            10th  16 GB     DDR4
# 620  APPLE              M1             M1            10th  16 GB     DDR4
# 621  APPLE              M1             M1            10th  32 GB     DDR4
# 622  APPLE              M1             M1            10th  16 GB     DDR4
#
#          ssd   hdd   os  os_bit graphic_card_gb  weight warranty Touchscreen  \
# 613   512 GB  0 GB  Mac  64-bit            0 GB  Casual   1 year          No
# 614   512 GB  0 GB  Mac  64-bit            0 GB  Casual   1 year          No
# 618  1024 GB  0 GB  Mac  64-bit            0 GB  Casual   1 year          No
# ...

# %%
lp_df_apple2.value_counts().sum()             #for counting values of apple
# Out:
# 7
